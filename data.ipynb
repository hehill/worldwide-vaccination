# %%
import pandas as pd
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

data_owid = "owid-covid-data.csv"

data_owid_df = pd.read_csv(data_owid)

# %%
#cleaning data/making tables
country = data_owid_df[["iso_code", "location", "continent", "population", "population_density", "gdp_per_capita", "extreme_poverty", "life_expectancy", "handwashing_facilities", "hospital_beds_per_thousand"]]
country.rename(columns= {"location": "country_name"}, inplace= True)
country.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py:5034: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#   iso_code country_name continent  population  population_density  \
# 0      AFG  Afghanistan      Asia  39835428.0              54.422
# 1      AFG  Afghanistan      Asia  39835428.0              54.422
# 2      AFG  Afghanistan      Asia  39835428.0              54.422
# 3      AFG  Afghanistan      Asia  39835428.0              54.422
# 4      AFG  Afghanistan      Asia  39835428.0              54.422
#
#    gdp_per_capita  extreme_poverty  life_expectancy  handwashing_facilities  \
# 0        1803.987              NaN            64.83                  37.746
# 1        1803.987              NaN            64.83                  37.746
# 2        1803.987              NaN            64.83                  37.746
# 3        1803.987              NaN            64.83                  37.746
# 4        1803.987              NaN            64.83                  37.746
#
#    hospital_beds_per_thousand
# 0                         0.5
# 1                         0.5
# 2                         0.5
# 3                         0.5
# 4                         0.5

# %%
policy = data_owid_df[["iso_code", "date", "stringency_index"]]
policy.head()
# Out:
#   iso_code        date  stringency_index
# 0      AFG  2020-02-24              8.33
# 1      AFG  2020-02-25              8.33
# 2      AFG  2020-02-26              8.33
# 3      AFG  2020-02-27              8.33
# 4      AFG  2020-02-28              8.33

# %%
cases = data_owid_df[["iso_code", "date", "total_cases_per_million", "new_cases_per_million", "new_cases_smoothed_per_million"]]
cases.head()
# Out:
#   iso_code        date  total_cases_per_million  new_cases_per_million  \
# 0      AFG  2020-02-24                    0.126                  0.126
# 1      AFG  2020-02-25                    0.126                  0.000
# 2      AFG  2020-02-26                    0.126                  0.000
# 3      AFG  2020-02-27                    0.126                  0.000
# 4      AFG  2020-02-28                    0.126                  0.000
#
#    new_cases_smoothed_per_million
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN

# %%
vaccines = data_owid_df[["iso_code", "date", "people_vaccinated_per_hundred", "people_fully_vaccinated_per_hundred", "total_boosters_per_hundred", "new_vaccinations_smoothed_per_million"]]
vaccines.head()
# Out:
#   iso_code        date  people_vaccinated_per_hundred  \
# 0      AFG  2020-02-24                            NaN
# 1      AFG  2020-02-25                            NaN
# 2      AFG  2020-02-26                            NaN
# 3      AFG  2020-02-27                            NaN
# 4      AFG  2020-02-28                            NaN
#
#    people_fully_vaccinated_per_hundred  total_boosters_per_hundred  \
# 0                                  NaN                         NaN
# 1                                  NaN                         NaN
# 2                                  NaN                         NaN
# 3                                  NaN                         NaN
# 4                                  NaN                         NaN
#
#    new_vaccinations_smoothed_per_million
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN

# %%
deaths = data_owid_df[["iso_code", "date", "total_deaths_per_million", "new_deaths_per_million", "new_deaths_smoothed_per_million", "excess_mortality_cumulative_per_million"]]
deaths.head()
# Out:
#   iso_code        date  total_deaths_per_million  new_deaths_per_million  \
# 0      AFG  2020-02-24                       NaN                     NaN
# 1      AFG  2020-02-25                       NaN                     NaN
# 2      AFG  2020-02-26                       NaN                     NaN
# 3      AFG  2020-02-27                       NaN                     NaN
# 4      AFG  2020-02-28                       NaN                     NaN
#
#    new_deaths_smoothed_per_million  excess_mortality_cumulative_per_million
# 0                              NaN                                      NaN
# 1                              NaN                                      NaN
# 2                              NaN                                      NaN
# 3                              NaN                                      NaN
# 4                              NaN                                      NaN

# %%
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
engine = create_engine(f'postgresql://postgres:1234@localhost:5432/COVID-19')
conn = engine.connect()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/tn/m51dm4nd5wv2rw2867yd_l_h0000gn/T/ipykernel_14974/109061809.py in <module>
#       3 from sqlalchemy.orm import Session
#       4 from sqlalchemy import create_engine, func
# ----> 5 engine = create_engine(f'postgresql://postgres:1234@localhost:5432/data_owid_df')
#       6 conn = engine.connect()
#
# <string> in create_engine(url, **kwargs)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sqlalchemy/util/deprecations.py in warned(fn, *args, **kwargs)
#     296                         stacklevel=3,
#     297                     )
# --> 298             return fn(*args, **kwargs)
#     299
#     300         doc = fn.__doc__ is not None and fn.__doc__ or ""
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sqlalchemy/engine/create.py in create_engine(url, **kwargs)
#     558             if k in kwargs:
#     559                 dbapi_args[k] = pop_kwarg(k)
# --> 560         dbapi = dialect_cls.dbapi(**dbapi_args)
#     561
#     562     dialect_args["dbapi"] = dbapi
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in dbapi(cls)
#     791     @classmethod
#     792     def dbapi(cls):
# --> 793         import psycopg2
#     794
#     795         return psycopg2
#
# ModuleNotFoundError: No module named 'psycopg2'

# %%
base = automap_base()

# %%
base.prepare(engine, reflect=True)

# %%
base.classes.keys()

# %%
country.to_sql(name='country', con=engine, if_exists='append', index=False)

# %%
cases.to_sql(name='cases', con=engine, if_exists='append', index=False)

# %%
deaths.to_sql(name='deaths', con=engine, if_exists='append', index=False)

# %%
vaccines.to_sql(name='vaccines', con=engine, if_exists='append', index=False)

# %%
policy.to_sql(name='policy', con=engine, if_exists='append', index=False)
